# %%
import pandas as pd

path_etat_voisin = r"C:\Users\L14\Desktop\LIVRAISON_13_02_2026\etat_parcelle_tonkpi_18-02-2026.csv"
path_maj_db = r"C:\Users\L14\Desktop\LIVRAISON_13_02_2026\correction_voisins_22_02_2026.xlsx"


etat_voisin = pd.read_csv(path_etat_voisin)
maj_voisin = pd.read_excel(path_maj_db, engine='openpyxl')

etat_voisin.set_index(keys="indice_unique_voisin", drop=False, inplace=True)
maj_voisin.set_index(keys="indice_unique_voisin", drop=False, inplace=True)

# Mise à jour propre
etat_voisin.update(maj_voisin[["designation_voisin"]])

# Afficher une ligne par index
etat_voisin.to_csv(r"C:\Users\L14\Desktop\LIVRAISON_13_02_2026\etat_parcelle_tonkpi_essai_22-02-2026.csv", encoding='utf-8')
# Out:
# C:\Users\L14\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\openpyxl\worksheet\_reader.py:313: UserWarning: Failed to load a conditional formatting rule. It will be discarded. Cause: expected <class 'openpyxl.worksheet.cell_range.MultiCellRange'>
#   warn(msg)

# %%
import pandas as pd
import os
import glob

formulaire_final = pd.DataFrame()
formulaires_with_droped_columns = []
extracted_columns = ['REGION', 'DEPARTEMENT', 'SOUS-PREFECTURE', 'VILLAGE', 'N°AFOR du village','GEOLOCALISATION DU VILLAGE', '_GEOLOCALISATION DU VILLAGE_latitude', '_GEOLOCALISATION DU VILLAGE_longitude', '_GEOLOCALISATION DU VILLAGE_altitude', '_GEOLOCALISATION DU VILLAGE_precision', 'Date prise de contact', 'REPRESENTANTS DU VILLAGE PRESENTS PRISE DE CONTACT', 'HOMMES REPRESENTANTS DU VILLAGE PRESENTS PRISE DE CONTACT du ${Date_prisecontact}', 'FEMMES REPRESENTANTES DU VILLAGE PRESENTES PRISE DE CONTACT du ${Date_prisecontact}', 'AUTORITES ADMINISTRATIVES PRESENTES PRISE DE CONTACT du ${Date_prisecontact}', 'SI AUTRE AUTORITE ADMINISTRATIVE PRISE DE CONTACT, PRECISER', 'HOMMES AUTORITES ADMINISTRATIVES PRESENTS PRISE DE CONTACT du ${Date_prisecontact}', 'FEMMES AUTORITES ADMINISTRATIVES PRESENTS PRISE DE CONTACT du ${Date_prisecontact}', 'PERSONNEL OF PRESENTES PRISE DE CONTACT du ${Date_prisecontact}', 'HOMMES PERSONNEL OF PRESENTS PRISE DE CONTACT du ${Date_prisecontact}', 'FEMMES PERSONNEL OF PRESENTS PRISE DE CONTACT du ${Date_prisecontact}', "AUTRE TYPE D'ACTEUR PRESENTS PRISE DE CONTACT", "HOMMES AUTRES TYPE D'ACTEURS  PRESENTS PRISE DE CONTACT du ${Date_prisecontact}", "FEMMES AUTRES TYPE D'ACTEURS  PRESENTS PRISE DE CONTACT du ${Date_prisecontact}", 'calculation_001', 'TOTAL HOMMES A LA PRISE DE CONTACT EST ${calculation_001}', 'calculation_002', 'TOTAL FEMMES A LA PRISE DE CONTACT EST ${calculation_002}', 'calculation', 'TOTAL H+F A LA PRISE DE CONTACT EST ${calculation}', 'SI AUTRE REPRESENTANTS DU VILLAGE, PRECISER', 'SI AUTRE PERSONNEL OF PRISE DE CONTACT, PRECISER', 'LE TOTAL DES PERSONNES PRESENTES EST DE ${calculation}', "DateCEREMONIE D'OUVERTURE", "REPRESENTANTS DU VILLAGE PRESENTS CEREMONIE D'OUVERTURE", "HOMMES REPRESENTANTS DU VILLAGE PRESENTS CEREMONIE D'OUVERTURE du ${Date_ouverture}", "FEMMES REPRESENTANTES DU VILLAGE PRESENTES CEREMONIE D'OUVERTURE du ${Date_ouverture}", "AUTORITES ADMINISTRATIVES PRESENTES CEREMONIE D'OUVERTURE du ${Date_ouverture}", "SI AUTRE AUTORITE ADMINISTRATIVE CEREMONIE D'OUVERTURE, PRECISER", "HOMMES AUTORITES ADMINISTRATIVES PRESENTS CEREMONIE D'OUVERTURE du ${Date_ouverture}", "FEMMES AUTORITES ADMINISTRATIVES PRESENTS CEREMONIE D'OUVERTURE du ${Date_ouverture}", "PERSONNEL OF PRESENTES CEREMONIE D'OUVERTURE du ${Date_ouverture}", "HOMMES PERSONNEL OF PRESENTS CEREMONIE D'OUVERTURE du ${Date_ouverture}", "FEMMES PERSONNEL OF PRESENTS CEREMONIE D'OUVERTURE du ${Date_ouverture}", "AUTRE TYPE D'ACTEUR PRESENTS CEREMONIE D'OUVERTURE", "HOMMES AUTRES TYPE D'ACTEURS  PRESENTS CEREMONIE D'OUVERTURE du ${Date_ouverture}", "FEMMES AUTRES TYPE D'ACTEURS  PRESENTS CEREMONIE D'OUVERTURE du ${Date_ouverture}", 'calculation_0012', "Total Hommes cérémonie d'ouverture est ${calculation_001}", 'calculation_0023', "Total Femmes cérémonie d'ouverture est ${calculation_002}", 'calculation4', "TOTAL H+F A LA CEREMONIE D'OUVERTURE EST DE ${calculation}", "COMMENTAIRES ÉVENTUELS SUR LE DÉROULEMENT DE LA CÉRÉMONIE D'OUVERTURE", "DateCEREMONIE D'OUVERTURE5", 'SI AUTRE REPRESENTANTS DU VILLAGE, PRECISER6', "HOMMES REPRESENTANTS DU VILLAGE PRESENTS CEREMONIE D'OUVERTURE du ${Date_prisecontact}", "FEMMES REPRESENTANTES DU VILLAGE PRESENTES CEREMONIE D'OUVERTURE du ${Date_prisecontact}", "HOMMES AUTORITES ADMINISTRATIVES PRESENTS CEREMONIE D'OUVERTURE du ${Date_prisecontact}", "FEMMES AUTORITES ADMINISTRATIVES PRESENTS CEREMONIE D'OUVERTURE du ${Date_prisecontact}", "SI AUTRE AUTORITE PERSONNEL OF CEREMONIE D'OUVERTURE, PRECISER", "HOMMES PERSONNEL OF PRESENTS CEREMONIE D'OUVERTURE du ${Date_prisecontact}", "FEMMES PERSONNEL OF PRESENTS CEREMONIE D'OUVERTURE du ${Date_prisecontact}", "HOMMES AUTRES TYPE D'ACTEURS  PRESENTS CEREMONIE D'OUVERTURE du ${Date_prisecontact}", "FEMMES AUTRES TYPE D'ACTEURS  PRESENTS CEREMONIE D'OUVERTURE du ${Date_prisecontact}", 'LE TOTAL DES PERSONNES PRESENTES EST DE ${calculation}7', 'Date de la sensibilisation', 'SUJET ABORDÉS', 'SI AUTRE  SUJET ABORDÉ A LA SENSIBILISATION DE MASSE, PRECISER', 'NOMBRE HOMMES REPRESENTANTS VILLAGE SENSIBILISATION DE MASSE', 'NOMBRE FEMMES REPRESENTANTES VILLAGE SENSIBILISATION DE MASSE', 'NOMBRE HOMMES ADMINISTRATION SENSIBILISATION DE MASSE', 'NOMBRE FEMMES ADMINISTRATION SENSIBILISATION DE MASSE', 'NOMBRE HOMMES OPERATEUR FONCIER SENSIBILISATION DE MASSE', 'NOMBRE FEMMES OPERATEUR FONCIER SENSIBILISATION DE MASSE', 'NOMBRE HOMMES AUTRE ACTEURS SENSIBILISATION DE MASSE', 'NOMBRE FEMMES AUTRE ACTEUR SENSIBILISATION DE MASSE', 'calculation8', 'TOTAL H+F Sensibilisation de masse est ${calculation}', 'date  Sensibilisation ou dialogue communautaire en groupe spécifique', 'SUJETS ABORDÉS DIALOGUE COMMUNAUTAIRE', 'SI AUTRE SUJETS ABORDÉS AU DIALOGUE COMMUNAUTAIRE, PRECISER', 'GROUPES RENCONTRÉS', 'SI AUTRE GROUPE RENCONTRÉ AU DIALOGUE COMMUNAUTAIRE, PRECISER', 'HOMMES PRESENTS AU DIALOGUE COMMUNAUTAIRE', 'FEMMES PRESENTES AU DIALOGUE COMMUNAUTAIRE', 'calculation_0019', 'TOTAL H+F PRESENTES AU DIALOGUE COMMUNAUTAIRE DU ${date_DC} EST DE ${calculation_001}', "IL Y-A T IL D'AUTRES TYPES DE SENSIBILSATION", 'date autres TYPES DE SENSIBILISATION', 'AUTRES TYPES DE SENSIBILISATION', 'SI AUTRES TYPES DE SENSIBILISATION, PRÉCISER', 'date sensibilisation des cadres', 'LIEU DE LA SENSIBILISATION', 'HOMMES PRESENTS A LA SENSIBILISATION DES CADRES', 'FEMMES PRESENTS A LA SENSIBILISATION DES CADRES', 'OBSERVATIONS', 'calculation_00210', 'TOTAL PERSONNES A LA SENSIBILISATION DES CADRE DU ${date_sensibilisationcadre} EST ${calculation_002}', "Information et sensibilisation relatives à l'équité, au genre et aux VBG/ EAS/ HS", "SI AUTRE SENSIBILISATION relatives à l'équité, au genre et aux VBG/ EAS/ HS, PRECISER", 'DECRIRE LA SENSIBILISATION EN LIEN AVEC Sensibilisation sur les Droits fonciers des femmes', 'DECRIRE LA SENSIBILISATION EN LIEN AVEC ${autre_vbg}', 'Informations et sensibilisation relatives aux sauvegardes environnementales', 'DECRIRE LA SENSIBILISATION EN LIEN AVEC ${sauvegarde_envi}', 'DATE FORMATION 1 CVGFR', 'FORMATION 1 CVGFR', 'FORMATION 1 CVGFR/Environnement juridique et institutionnel du foncier rural', 'FORMATION 1 CVGFR/Missions et rôles du CVGFR dans les processus de sécurisation foncière', 'FORMATION 1 CVGFR/Appui à la rédaction du règlement intérieur', 'FORMATION 1 CVGFR/Dispositions relatives à l’équité concernant le genre', "Nombre d'hommes présents à la FORMATION 1 du CVGFR", 'Nombre de femmes présentes à la FORMATION 1 du CVGFR', 'DATE FORMATION 2 CVGFR', 'FORMATION 2  CVGFR', 'FORMATION 2  CVGFR/Contractualisation Foncière', 'FORMATION 2  CVGFR/Dispositions relatives à l’équité concernant le genre, dans la contractualisation', 'FORMATION 2  CVGFR/Appui à la rédaction du règlement intérieur', 'FORMATION 2  CVGFR/Finalisation du règlement intérieur', "Nombre d'hommes présents à la FORMATION 2 du CVGFR", 'Nombre de femmes présentes à la FORMATION 2 du CVGFR', 'DATE FORMATION 3 CVGFR', 'FORMATION 3  CVGFR', 'FORMATION 3  CVGFR/Tenue des registres, archivage et conservation des documents fonciers', "Nombre d'hommes présents à la FORMATION 3 du CVGFR", 'Nombre de femmes présentes à la FORMATION 3 du CVGFR', 'calculation_019', 'TOTAL DES HOMMES Présents lors des 3 séances de formations du CVGFR est ${calculation_019}', 'calculation_020', 'TOTAL DES FEMMES Présentes lors des 3 séances de formations du CVGFR est ${calculation_020}', 'calculation_021', 'TOTAL H+F présents lors des 3 séances de FORMATION DES CVGFR est ${calculation_021}', 'Moyenne du nombre de personnes formées  Au niveau du CVGFR est ${calculation_021}/3', '9. DIFFICULTES RENCONTREES', '9. DIFFICULTES RENCONTREES/CVGFR', '9. DIFFICULTES RENCONTREES/Litiges entre individus', '9. DIFFICULTES RENCONTREES/Relations intrafamiliales', '9. DIFFICULTES RENCONTREES/Relations intercommunautaires', '9. DIFFICULTES RENCONTREES/Genre', '9. DIFFICULTES RENCONTREES/État-civil', '9. DIFFICULTES RENCONTREES/Sauvegarde environnementale', '9. DIFFICULTES RENCONTREES/Autres (selon les spécificités du village)', 'DIFFICULTES CVGFR', 'DIFFICULTES Litiges entre individus', 'DIFFICULTES Relations intrafamiliales', 'DIFFICULTES Relations intercommunautaires', 'DIFFICULTES Genre', 'DIFFICULTES État-civil', 'DIFFICULTES Sauvegarde environnementale', 'DIFFICULTES Autres (selon les spécificités du village)', 'RECOMMANDATION']
formulaires = glob.glob('/home/userpc/PRESFOR/TRAITEMENTS/formulaires_isf/*.xlsx')

print(f"Nombre de fichiers excels trouvés : {len(formulaires)}")

# Lire les fichiers dans une liste
dfs = [pd.read_excel(os.path.join(formulaire), engine='openpyxl') for formulaire in formulaires]

df_base = dfs[3]

# Fusionner les autres fichiers avec la base, sur la colonne 'VILLAGE'
for formulaire in formulaires:
        df = pd.read_excel(formulaire,engine='openpyxl')
        columns_to_drop = [item for item in df if item.startswith("REPRESENTANTS DU VILLAGE PRESENTS CEREMONIE D'OUVERTURE/") or item.startswith("AUTORITES ADMINISTRATIVES PRESENTES CEREMONIE D'OUVERTURE du ${Date_prisecontact}/") or item.startswith("PERSONNEL OF PRESENTES CEREMONIE D'OUVERTURE du ${Date_prisecontact}/") or item.startswith('REPRESENTANTS DU VILLAGE PRESENTS PRISE DE CONTACT/') or item.startswith('AUTORITES ADMINISTRATIVES PRESENTES PRISE DE CONTACT du ${Date_prisecontact}/') or item.startswith('PERSONNEL OF PRESENTES PRISE DE CONTACT du ${Date_prisecontact}/') or item.startswith("9. DIFFICULTES RENCONTREES/") or item.startswith("FORMATION 1 CVGFR/") or item.startswith("FORMATION 2 CVGFR/") or item.startswith("FORMATION 3 CVGFR/")]
        columns_to_drop.extend(['start', 'end','_id', '_uuid', '_submission_time', '_validation_status', '_notes', '_status', '_submitted_by', '__version__', '_tags', '_index'])
        
        df = df.drop(columns=columns_to_drop,axis=1)
    
        df.to_excel(f"{formulaire.split('/')[-1]}")
# Out:
# Nombre de fichiers excels trouvés : 5
# /home/userpc/PRESFOR/TRAITEMENTS/formulaires_isf/FORMULAIRE_3_INFORMATION_ET_SENSIBILISATION_DES_ACTEURS_VILLAGEOIS_-_latest_version_-_labels_-.xlsx
